# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('./bin/target_models/vp_target.txt')

# %%
np.shape(data)
data = np.rot90(data)

# %%
plt.imshow(data)

# %%
data
# Out:
# array([[1960., 1960., 1960., ..., 1960., 1960., 1960.],
#        [1960., 1960., 1960., ..., 1960., 1960., 1960.],
#        [1960., 1960., 1960., ..., 1960., 1960., 1960.],
#        ...,
#        [2080., 2080., 2080., ..., 2080., 2080., 2080.],
#        [2080., 2080., 2080., ..., 2080., 2080., 2080.],
#        [2080., 2080., 2080., ..., 2080., 2080., 2080.]])

# %%
data = np.loadtxt('./bin/starting_models/vp_starting_after_burnin.txt')

# %%
data = np.rot90(data)
plt.imshow(data)

# %%
plt.plot(data[:,100])

# %%
data = np.loadtxt('./bin/sources_shot_0.txt')

# %%
np.shape(data)
# Out:
# (7, 8000)
